# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 11.09.2020
#
# Мягкий дедлайн: 04:59MSK 21.09.2020 (но лучше сдайте пораньше и успейте выспаться)
#
# Жесткий дедлайн: 23:59MSK 24.09.2020

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
a = [1, 2, 3]
b = [3, 4, 5]
list(map((lambda x, y:x+y), a, b))
# Out:
# [4, 6, 8]

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
data = pd.read_csv('_end_seminar - Sheet1.csv')

# %%
len(data) #361 элемент
data.head(20)
# Out:
#               timestamp                                id  rating  18_group  \
# 0   2020-05-15 01:12:51  93ff79a51cd602f1dd3028ba2c129503     698     181.0
# 1   2020-05-15 02:46:48  26b01b1c4cd5656bab18d24c548834fb     647     181.0
# 2   2020-05-15 03:12:41  30f3653fc176d54e89ac3179c455c6dd     624     185.0
# 3   2020-05-15 04:43:09  1528f0eaa027580820ccf0d92a53ad68     579     182.0
# 4   2020-05-15 07:47:17  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0
# 5   2020-05-15 09:10:19  d0d8ff53ed5b119f9056068e954256c6     591     187.0
# 6   2020-05-15 11:42:17  e4caca755ee0bdd711e18fb8084958b5     724     181.0
# 7   2020-05-15 12:11:43  8047c18b3c531c6f47931e0744f3e028     566     187.0
# 8   2020-05-15 13:21:41  e8b314842f176be9051d14a07cb156cb     618     181.0
# 9   2020-05-15 13:29:11  d6c079f1ff869c8c84fa3ed30bd67e0e     733     181.0
# 10  2020-05-15 13:46:32  57c331c5a1b473501d86dfd23421bb5c     623     186.0
# ...

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
print("Количество заявок из групп 18-ого года набора", data['18_group'].count())
print("Количество заявок из групп 17-ого года набора", data['17_group'].count())
# Out:
# Количество заявок из групп 18-ого года набора 223
# Количество заявок из групп 17-ого года набора 138

# %%
a = set()
for elem in data['percentile']:
    a.add(elem)
print(len(a))
# Так как всего наблюдений 361, уникальных перцентилей 346, значит есть студенты с равными перцентилями
# Out:
# 346

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
data.isna().sum() 
# Тут вывел количество пропусков в каждой из колонок
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
# 17_group числом, 18_group числом, is_mi числом
data['18_group'] = data['18_group'].fillna(0)
data['17_group']= data['17_group'].fillna(0)
data['is_mi'] = data['is_mi'].fillna(0)
data['is_first_time'] = data['is_first_time'].fillna('')
data['blended'] = data['blended'].fillna('')
data['is_ml_student'] = data['is_ml_student'].fillna('')

# %%
data.isna().sum() 
data.head()
# Out:
#              timestamp                                id  rating  18_group  \
# 0  2020-05-15 01:12:51  93ff79a51cd602f1dd3028ba2c129503     698     181.0
# 1  2020-05-15 02:46:48  26b01b1c4cd5656bab18d24c548834fb     647     181.0
# 2  2020-05-15 03:12:41  30f3653fc176d54e89ac3179c455c6dd     624     185.0
# 3  2020-05-15 04:43:09  1528f0eaa027580820ccf0d92a53ad68     579     182.0
# 4  2020-05-15 07:47:17  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0
#
#    is_mi                             fall_1  \
# 0    0.0                           Язык SQL
# 1    0.0  Высокопроизводительные вычисления
# 2    0.0   Безопасность компьютерных систем
# 3    0.0        Statistical Learning Theory
# 4    0.0  Высокопроизводительные вычисления
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# ...

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию.

# %%
data['is_first_time'].value_counts()
# как видно 51 ответа "Нет"
# Out:
# Да     308
# Нет     51
#          2
# Name: is_first_time, dtype: int64

# %%
k = len(data['id'])
ind_for_del = []
for i in range(0, k):
    j = i+1
    while (j < k):
        if (data['id'][i] == data['id'][j]):
            print(data['id'][i], i, j, data['is_first_time'][i], data['is_first_time'][j]) #тут надо удалять первое вхождение
            ind_for_del.append(i)
        j += 1
# Out:
# a65d50ef4fadfac64508a54e972d8623 22 23 Да Нет
# b121e4d7d62387cd5199cca464a34a6d 29 30 Да Нет
# 5ee2ad618729a6dc3bdb7f2858826ef0 97 98 Да Нет
# 5c49473012411a1eee72f8ea63767adf 121 126 Да Нет
# ffc58d371e2f52e1c7f45d49d3d629d0 129 139 Да Нет
# f8fab519d78047712c06798c8b7fe38f 141 150 Да Нет
# 9015b809a29fb65ce23d7addf16d770d 144 152 Да Нет
# 8aa0f1b7331b49464174b02cd693be52 174 176 Да Нет
# 86c24daaa62246142d46ee58534a65e0 186 192 Да Нет
# 47e2d8bbb630bc2d9b3fbf98fe77cffb 196 204 Да Нет
# 906692ccd33f59058380aac1598c5480 257 259 Да Нет
# 9a66d84568b8017d98eb2e678b57296b 300 302 Да Нет
# d9c068e5578253c2b0721558dd0813e1 321 325 Да Нет
# 50f6d5b6a7fd6c8b1b8959f9ce1f808d 333 342 Да Нет

# %%
ind_for_del
# Out:
# [22, 29, 97, 121, 129, 141, 144, 174, 186, 196, 257, 300, 321, 333]

# %%
for elem in ind_for_del:
    data.drop([elem], inplace = True) #удалил одинаковые вхождения

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
data['blended'].value_counts() #существуют курсы Devops, Соревновательный анализ данных, Введение в дифференциальную геометрию
# Out:
#                                          213
# DevOps                                    87
# Соревновательный анализ данных            32
# Введение в дифференциальную геометрию     15
# Name: blended, dtype: int64

# %%
print("Средний рейтинг -  Devops", data[data.blended=='DevOps'].rating.mean())
print("Средний рейтинг - Соревновательный анализ данных", data[data.blended=='Соревновательный анализ данных'].rating.mean())
print("Средний рейтинг - Введение в дифференциальную геометрию", data[data.blended=='Введение в дифференциальную геометрию'].rating.mean())
print("На курсе Введение в дифф геометрию собрались студенты с самым высоким рейтингом")
# Out:
# Средний рейтинг -  Devops 1154.1724137931035
# Средний рейтинг - Соревновательный анализ данных 1144.21875
# Средний рейтинг - Введение в дифференциальную геометрию 1210.7333333333333
# На курсе Введение в дифф геометрию собрались студенты с самым высоким рейтингом

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.

# %%
unique = []
for i in range(0, 361):
    unique.append(i)
for elem in ind_for_del: #чтобы потом мог итерироваться по объектам, не обращаясь к тем, которые удалил
    unique.remove(elem)

# %%
d = {}
for i in range(len(unique)):
    cur_cl = []
    cur_cl.append(data.fall_1[unique[i]])
    cur_cl.append(data.fall_2[unique[i]])
    cur_cl.append(data.fall_3[unique[i]])
    cur_cl.append(data.spring_1[unique[i]])
    cur_cl.append(data.spring_2[unique[i]])
    cur_cl.append(data.spring_3[unique[i]])
    cur_cl.append(data.blended[unique[i]])
    for j in range(i+1, len(unique)):
        cur_cl1 = []
        cur_cl1.append(data.fall_1[unique[j]])
        cur_cl1.append(data.fall_2[unique[j]])
        cur_cl1.append(data.fall_3[unique[j]])
        cur_cl1.append(data.spring_1[unique[j]])
        cur_cl1.append(data.spring_2[unique[j]])
        cur_cl1.append(data.spring_3[unique[j]])
        cur_cl1.append(data.blended[unique[j]])
        if (cur_cl == cur_cl1):
            el = tuple(cur_cl)
            if el in d:
                value = d[el]
                d[el]=value+1
            else:
                d[el]=1
            #print(unique[i],unique[j] , cur_cl)
ans = 0
for elem in d:
    ans += 1
    print("Искомый набор - ", elem, "Количество студентов, выбравшее этот набор - ",  d[elem])
    print("\n")
print("Общее количество наборов = ", ans)
# Out:
# Искомый набор -  ('Безопасность компьютерных систем', 'Высокопроизводительные вычисления', 'Язык SQL', 'Компьютерные сети', 'Промышленное программирование на языке Java', 'Дискретная оптимизация', '') Количество студентов, выбравшее этот набор -  3
#
#
# Искомый набор -  ('Безопасность компьютерных систем', 'Теория баз данных', 'Язык SQL', 'Машинное обучение 2', 'Компьютерные сети', 'Промышленное программирование на языке Java', '') Количество студентов, выбравшее этот набор -  1
#
#
# Искомый набор -  ('Безопасность компьютерных систем', 'Высокопроизводительные вычисления', 'Язык SQL', 'Промышленное программирование на языке Java', 'Компьютерные сети', 'Системы баз данных', '') Количество студентов, выбравшее этот набор -  1
#
#
# ...

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
'''print(data['fall_1'].value())
print(data['fall_2'].value_counts())
print("\n")
print(data['spring_1'].value_counts())'''
a1 = set()

for i in range (len(data.fall_1.unique())):
    a1.add(data.fall_1.unique()[i])
for i in range (len(data.fall_2.unique())):
    a1.add(data.fall_2.unique()[i])
for i in range (len(data.fall_3.unique())):
    a1.add(data.fall_3.unique()[i])
for i in range (len(data.spring_1.unique())):
    a1.add(data.spring_1.unique()[i])
for i in range (len(data.spring_2.unique())):
    a1.add(data.spring_2.unique()[i])
for i in range (len(data.spring_1.unique())):
    a1.add(data.spring_1.unique()[i])
a2 = set()
p = data[data["18_group"] > 0].fall_1.unique()
for i in range(len(p)):
    a2.add(p[i])
p = data[data["18_group"] > 0].fall_2.unique()
for i in range(len(p)):
    a2.add(p[i])
p = data[data["18_group"] > 0].fall_3.unique()
for i in range(len(p)):
    a2.add(p[i])
p = data[data["18_group"] > 0].spring_1.unique()
for i in range(len(p)):
    a2.add(p[i])
p = data[data["18_group"] > 0].spring_2.unique()
for i in range(len(p)):
    a2.add(p[i])   
p = data[data["18_group"] > 0].spring_3.unique()
for i in range(len(p)):
    a2.add(p[i])

a3 = set()
p = data[data["17_group"] > 0].fall_1.unique()
for i in range(len(p)):
    a3.add(p[i])
p = data[data["17_group"] > 0].fall_2.unique()
for i in range(len(p)):
    a3.add(p[i])
p = data[data["17_group"] > 0].fall_3.unique()
for i in range(len(p)):
    a3.add(p[i])
p = data[data["17_group"] > 0].spring_1.unique()
for i in range(len(p)):
    a3.add(p[i])
p = data[data["17_group"] > 0].spring_2.unique()
for i in range(len(p)):
    a3.add(p[i])   
p = data[data["17_group"] > 0].spring_3.unique()
for i in range(len(p)):
    a3.add(p[i])
a4 = a2
print(" Все курсы, в 2018", a2)
print(" Все курсы, в 2017", a3)
# Out:
#  Все курсы, в 2018 {'Дополнительные главы прикладной статистики', 'Сбор и обработка данных с помощью краудсорсинга', 'Принятие решений в условиях риска и неопределённости', 'Матричные вычисления', 'Численные методы', 'Машинное обучение 2', 'Системы баз данных', 'Язык SQL', 'Компьютерные сети', 'Промышленное программирование на языке Java', 'Теория баз данных', 'Безопасность компьютерных систем', 'Statistical Learning Theory', 'Дискретная оптимизация', 'Высокопроизводительные вычисления', 'Моделирование временных рядов', 'Анализ данных в бизнесе'}
# ...

# %%
print("Курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.")
a4.intersection_update(a3)
print(a4)
# объединение данных множеств показывает данные курсы
# Out:
# Курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.
# {'Сбор и обработка данных с помощью краудсорсинга', 'Численные методы', 'Безопасность компьютерных систем', 'Принятие решений в условиях риска и неопределённости', 'Statistical Learning Theory', 'Высокопроизводительные вычисления', 'Моделирование временных рядов'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
print("Курсы, которые предлагались только студентам 18-ого года")
print("Матричные вычисления, ", "Язык SQL, ", "Машинное обучение 2, ", "Анализ данных в бизнесе, ", 'Системы баз данных, ', 'Промышленное программирование на языке Java, ', 'Дискретная оптимизация, ', 'Дополнительные главы прикладной статистики, ','Теория баз данных, ', 'Компьютерные сети' )
print("\n")
print("Курсы, которые предлагались только студентам 17-ого года")
print('Генеративные модели в машинном обучении, ', 'Методы сжатия и передачи медиаданных, ', 'Анализ неструктурированных данных, ', 'Глубинное обучение в обработке звука, ', 'Байесовские методы машинного обучения, ', 'Конфликты и кооперация, ', 'Компьютерное зрение, ', 'Символьные вычисления, ', 'Обучение с подкреплением, ', 'Проектирование и разработка высоконагруженных сервисов' )
# это сделал руками так как функции set.difference_update почему-то не работают
# Out:
# Курсы, которые предлагались только студентам 18-ого года
# Матричные вычисления,  Язык SQL,  Машинное обучение 2,  Анализ данных в бизнесе,  Системы баз данных,  Промышленное программирование на языке Java,  Дискретная оптимизация,  Дополнительные главы прикладной статистики,  Теория баз данных,  Компьютерные сети
#
#
# Курсы, которые предлагались только студентам 17-ого года
# Генеративные модели в машинном обучении,  Методы сжатия и передачи медиаданных,  Анализ неструктурированных данных,  Глубинное обучение в обработке звука,  Байесовские методы машинного обучения,  Конфликты и кооперация,  Компьютерное зрение,  Символьные вычисления,  Обучение с подкреплением,  Проектирование и разработка высоконагруженных сервисов

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
data['timestamp'] = data['timestamp'].apply(lambda x: x.split(' ')[0]) #чтобы было удобнее строить график 
data.head()
# Out:
#     timestamp                                id  rating  18_group  is_mi  \
# 0  2020-05-15  93ff79a51cd602f1dd3028ba2c129503     698     181.0    0.0
# 1  2020-05-15  26b01b1c4cd5656bab18d24c548834fb     647     181.0    0.0
# 2  2020-05-15  30f3653fc176d54e89ac3179c455c6dd     624     185.0    0.0
# 3  2020-05-15  1528f0eaa027580820ccf0d92a53ad68     579     182.0    0.0
# 4  2020-05-15  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0    0.0
#
#                               fall_1                             fall_2  \
# 0                           Язык SQL  Высокопроизводительные вычисления
# 1  Высокопроизводительные вычисления   Безопасность компьютерных систем
# 2   Безопасность компьютерных систем               Матричные вычисления
# 3        Statistical Learning Theory  Высокопроизводительные вычисления
# 4  Высокопроизводительные вычисления   Безопасность компьютерных систем
#
#                           fall_3                spring_1  \
# ...

# %%
fig, ax = plt.subplots()
ax = sns.countplot(y='fall_1', data=data)

# %%
gr = data.groupby('timestamp').mean()['rating']
fig.suptitle('График средних рейтингов по полученным дням')
fig, axs = plt.subplots(1, 1, figsize=(10, 6), sharex=True)
axs.plot(gr)
axs.set_ylabel('Средний рейтинг')
# Out:
# Text(0, 0.5, 'Средний рейтинг')

# %%
df = data

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно.
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * 181, 182 - МОП; 183 - ТИ; 184 - АДИС; 185, 186 - РС; 187 - АПР; 188 - МИ
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
data['Number_spring_courses']=1
for i in range(len(unique)):
    if (data['17_group'][unique[i]] == 171 or data['17_group'][unique[i]] == 172 or data['17_group'][unique[i]] == 173 or data['is_mi'][unique[i]] == True ):
        data['Number_spring_courses'][unique[i]] = 2
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = data

# %%
# insert your new column name as str

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22']['Number_spring_courses'] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403']['Number_spring_courses'] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c']['Number_spring_courses'] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5']['Number_spring_courses'] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %%
ans1 = data.groupby('fall_1').count()[['id']]
ans2 = data[(data['17_group'] == 171) | (data['17_group'] == 172) | (data['17_group'] == 173) | (data['is_mi'] == 1)].groupby('fall_2').count()[['id']]

# %%
print(ans1)
print("\n")
print(ans2)
# Out:
#                                                      id
# fall_1
# Statistical Learning Theory                          25
# Анализ неструктурированных данных                    32
# Байесовские методы машинного обучения                16
# Безопасность компьютерных систем                    110
# Высокопроизводительные вычисления                    41
# Глубинное обучение в обработке звука                 10
# Матричные вычисления                                 14
# Моделирование временных рядов                        22
# Принятие решений в условиях риска и неопределён...    5
# Сбор и обработка данных с помощью краудсорсинга      34
# Теория баз данных                                    11
# Язык SQL                                             27
#
#
#                                                     id
# fall_2
# Statistical Learning Theory                          8
# Анализ неструктурированных данных                   16
# ...

# %%
ans3 = ans1+ans2
# как видно отсюда Statistical learning theory полностью распределится между студентами, ибо 34<60
# Анализ неструктурированных данных полностью будет распределен, ибо на нем нет ограничений
# Байесовские методы будут распределены между учащимися, 24 < 30
# Высокопроизводительные вычисления будут распределены, 48<60
#Глубинно вычисление полностью распределено, 24 < 30
#...
# Не распределены некоторые студенты будут: Безопасность компьюетрных систем (116>30), Моделирование временных рядов (31>30)
# , Сбор и обработка данных с помощью краудсорсинга (50>30)
print(ans3)
# Out:
#                                                      id
# fall_1
# Statistical Learning Theory                          33
# Анализ неструктурированных данных                    48
# Байесовские методы машинного обучения                24
# Безопасность компьютерных систем                    116
# Высокопроизводительные вычисления                    45
# Глубинное обучение в обработке звука                 23
# Матричные вычисления                                 15
# Моделирование временных рядов                        31
# Принятие решений в условиях риска и неопределён...    8
# Сбор и обработка данных с помощью краудсорсинга      50
# Теория баз данных                                    14
# Язык SQL                                             29

# %%
classes = ['Statistical Learning Theory', 'Анализ неструктурированных данных','Байесовские методы машинного обучения','Безопасность компьютерных систем','Высокопроизводительные вычисления', 'Глубинное обучение в обработке звука','Матричные вычисления', 'Моделирование временных рядов','Принятие решений в условиях риска и неопределённости','Сбор и обработка данных с помощью краудсорсинга','Теория баз данных','Язык SQL']

# %%
for elem in classes:
    ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile')
    print(elem, len(ans))
# Out:
# Statistical Learning Theory 33
# Анализ неструктурированных данных 48
# Байесовские методы машинного обучения 24
# Безопасность компьютерных систем 115
# Высокопроизводительные вычисления 44
# Глубинное обучение в обработке звука 23
# Матричные вычисления 15
# Моделирование временных рядов 31
# Принятие решений в условиях риска и неопределённости 8
# Сбор и обработка данных с помощью краудсорсинга 50
# Теория баз данных 14
# Язык SQL 29

# %%
final_ = []
for elem in classes:
    ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile') #данный запрос находит тех и тех
    if ((elem == 'Statistical Learning Theory') | (elem == 'Анализ неструктурированных данных') | (elem == 'Высокопроизводительные вычисления')):
        k = [] #данные предметы проходят по количеству человек(<60)
    else:
        ans = ans[0:30] # в остальных случаях обрезаю после 30 и далее
    for cur in ans["id"]:
        #if ((cur == "e0fceae1e285f737630bb6123a1bd85d") or (cur == "7fcf56aae6836855a689000a50e80360")): 
        #    continue
        #else:
            #if (cur == 'ffc58d371e2f52e1c7f45d49d3d629d0'):
            #    print("YES")
            final_.append([cur, elem])
final_ = sorted(final_)

# %%
answer_for_fall = []
count = 0
i = 0
while (i < len(final_)-1):
    if (final_[i][0] == final_[i+1][0]):
        answer_for_fall.append([final_[i][0], final_[i][1], final_[i+1][1]])
        i += 2
        count += 1
    else:
        if (list(data[data['id'] == final_[i][0]].Number_spring_courses) == [2]):
            answer_for_fall.append([final_[i][0], final_[i][1],"???"])
        else:
            answer_for_fall.append([final_[i][0], final_[i][1],"-"])
        count += 1
        i += 1
if (i == len(final_)-1):
    if (list(data[data['id'] == final_[i][0]].Number_spring_courses) == [2]):
        answer_for_fall.append([final_[i][0], final_[i][1],"???"])
    else:
        answer_for_fall.append([final_[i][0], final_[i][1],"-"])

        # объединение с остальными, что остались
un_id =  set(data['id']) 
un_final_id = set()
for elem in answer_for_fall:
    un_final_id.add(elem[0])
un_id.difference_update(un_final_id)


for elem in un_id:
    if (list(data[data['id'] == elem].Number_spring_courses) == [2]):
        answer_for_fall.append([elem, "???", "???"]) #в данном случае только обработка ???, ??? -> если никуда не попал человек и у него два курса
    else:
        answer_for_fall.append([elem, "???", "-"])

# %%
data['Last_col'] = NaN
data['First_col'] = NaN

# %%
data['First_col'] = NaN
for elem in classes:
    ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile') 
    data.loc[data['id'] == list(ans['id'])[0], "First_col"] = True

# %%
df = data

# %%
data['Last_col'] = NaN
classes1 = ['Высокопроизводительные вычисления','Statistical Learning Theory','Анализ неструктурированных данных']
classes2 = ['Байесовские методы машинного обучения','Безопасность компьютерных систем', 'Глубинное обучение в обработке звука','Матричные вычисления', 'Моделирование временных рядов','Принятие решений в условиях риска и неопределённости','Сбор и обработка данных с помощью краудсорсинга','Теория баз данных','Язык SQL'] 
for elem in classes1:
    ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile') 
    data.loc[data['id'] == list(ans['id'])[len(list(ans['id']))-1], "Last_col"] = True
    
    
for elem in classes2:
    ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile') 
    ans = ans[:30]
    data.loc[data['id'] == list(ans['id'])[len(list(ans['id']))-1], "Last_col"] = True

for elem in classes:
     ans = data[(data['fall_1'] == elem) | ((data['fall_2'] == elem) &((data['17_group'] == 173)  | (data['17_group'] == 172)  | (data['17_group'] == 171) |(data['is_mi'] == 1) ))].sort_values('percentile') 
     
     data.loc[data['id'] == list(ans['id'])[0], "First_col"]

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name =    'First_col'   # insert name of your new column with is_first_place as str
last_col_name =   'Last_col'   # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()

# тут должен пристутствоввать крайний, кто входит на курс
assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# 2 волна
classes = ['Statistical Learning Theory', 'Анализ неструктурированных данных','Байесовские методы машинного обучения','Безопасность компьютерных систем','Высокопроизводительные вычисления', 'Глубинное обучение в обработке звука','Матричные вычисления', 'Моделирование временных рядов','Принятие решений в условиях риска и неопределённости','Сбор и обработка данных с помощью краудсорсинга','Теория баз данных','Язык SQL'] 
classes_num = [27, 100, 6, 0, 16, 7, 15, 0, 22, 0, 16, 1] # проверить на верность этот массив
wave_2 = []

df2 = pd.DataFrame(columns = ['id','fall_next', 'course_1', 'course_2', 'percentile', 'Number_spring_courses'])
cur = 0
final_2= []    
for elem in answer_for_fall:
    if (elem[1] != '???' and elem[2] != '???'):
        wave_2.append(elem)
        
    if (elem[2] == '???'): # это значит, что человеку нужно было выбрать 2 курса -> добавляю 3 курс по выбору
        #print(elem[0], elem[1], elem[2])
        if (elem[1] == '???'):
            df2.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_3']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
            cur += 1
        else:
            if ([elem[1]] == list(data[data['id'] == elem[0]]['fall_3'])): #не добавляю человека, который уже имел такой предмет
                #print(elem[0], elem[1])
                continue
            else:
                df2.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_3']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
                cur += 1
        
    if (elem[2] == '-' and elem[1] == '???'): #это значит, что человеку нужно было выбрать 1 курс -> добавляю 2 курс по выбору
        df2.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_2']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
        cur += 1
        #print(elem[0], cur)
#print(len(wave_2))
df2['fall_next'] = df2['fall_next'].apply(lambda x:x[0])
df2['percentile'] = df2['percentile'].apply(lambda x:x[0])
df2['Number_spring_courses'] = df2['Number_spring_courses'].apply(lambda x:x[0])

df2.groupby('fall_next').count()
# Out:
#                                                     id  course_1  course_2  \
# fall_next
# Statistical Learning Theory                          8         8         8
# Анализ неструктурированных данных                    5         5         5
# Байесовские методы машинного обучения                1         1         1
# Безопасность компьютерных систем                     5         5         5
# Высокопроизводительные вычисления                   25        25        25
# Глубинное обучение в обработке звука                 7         7         7
# Матричные вычисления                                 9         9         9
# Моделирование временных рядов                       10        10        10
# Принятие решений в условиях риска и неопределён...   1         1         1
# Сбор и обработка данных с помощью краудсорсинга     15        15        15
# Теория баз данных                                    4         4         4
# ...

# %%
print(len(wave_2))
for i in range(len(classes)):
    ans = df2[df2['fall_next'] == classes[i]].sort_values('percentile')
    ans = ans[0:classes_num[i]]
    for man in ans['id']:
       final_2.append([man, classes[i]]) #тут иду по id которые прошли по второй волне, тут их 52.(Могут быт челы, которые хоть и прошли, но у них курсы с пред совпадают) Должно остаться из 105 -> 54
    
       if (list(ans[ans['id'] == man].Number_spring_courses) == [1]):
             wave_2.append([man, classes[i] , '-']) #полностью закрыты. Тут 35 человек проходят
                
       if (list(ans[ans['id'] == man].Number_spring_courses) == [2]):
            if (list(ans[ans['id'] == man].course_1) == ['???']): # челы у кого первый курс '???'
                wave_2.append([man, classes[i], '???']) # дальше его смотреть не надо, он и по третьей не пройдет
                print(man, classes[i], "HERE1")
            else: #челы у кого первый курс уже выбран был, второй '???'
                if (list(ans[ans['id'] == man].course_1) == [classes[i]]): # чел который по второй волне проходит на курс где был - послать на третью волну
                    for fl in ans[ans['id'] == man].course_1:
                         wave_2.append([man, fl, '???']) # дальше его смотреть не надо, дальше не проходит по третьей
                         print(man, fl, "HERE2")
                    #print(man, list(ans[ans['id'] == man].course_1) )
                else:
                    for fl in ans[ans['id'] == man].course_1:
                        wave_2.append([man, fl , classes[i]]) #закрыли свой второй приоритет

print(len(wave_2))
#тут смотрю на оставшихся и обрабатываю их
un_id1 =  set(data['id'])
un_final_id1 = set()
print(len(un_id1), "un_id1")
for elem in wave_2:
    un_final_id1.add(elem[0])
un_id1.difference_update(un_final_id1)
print(len(un_id1), "un_id1")
for elem in un_id1:
    for k in answer_for_fall:
        if (elem == k[0]):
            wave_2.append(k)
print(len(wave_2))
# Out:
# 242
# d40cbae8cfc9e6c5d05831ef7e122f3e Анализ неструктурированных данных HERE1
# 294
# 347 un_id1
# 53 un_id1
# 347

# %%
#финальный вывод для второй волны
#answer_for_fall.to_csv('first_wave.csv', index=False)
#data.to_csv('first_wave.csv', index=False)
# составление таблички и ее вывод в типе csv
df2_final = pd.DataFrame(columns = ['id', 'course1', 'course2'])
cur = 0
for elem in wave_2:
    df2_final.loc[cur] = [elem[0], elem[1], elem[2]]
    cur += 1
#data_fin_ = pd.Series(answer_for_fall)
#data_fin_.head()[0]
df2_final.to_csv('second_wave.csv', index=False)

# %%
cur = 0
d = {}
for elem in wave_2:
    if (elem[1] !='???'):
        if elem[1] in d:
            value = d[elem[1]]
            d[elem[1]]=value+1
        else:
            d[elem[1]]=1
        
    if (elem[2] != '???'):
        if elem[2] in d:
            value = d[elem[2]]
            d[elem[2]]=value+1
        else:
            d[elem[2]]=1
        
print(d)
# Out:
# {'Безопасность компьютерных систем': 30, '-': 258, 'Теория баз данных': 18, 'Высокопроизводительные вычисления': 60, 'Матричные вычисления': 24, 'Сбор и обработка данных с помощью краудсорсинга': 30, 'Язык SQL': 30, 'Statistical Learning Theory': 41, 'Глубинное обучение в обработке звука': 30, 'Анализ неструктурированных данных': 53, 'Байесовские методы машинного обучения': 25, 'Моделирование временных рядов': 30, 'Принятие решений в условиях риска и неопределённости': 9}

# %%
# 3 волна
wave_3 = []
cur = 0
df3 = pd.DataFrame(columns = ['id','fall_next', 'course_1', 'course_2', 'percentile', 'Number_spring_courses'])
for elem in wave_2:
    if (elem[1] != '???' and elem[2] != '???'):
        wave_3.append(elem)
    
    if (elem[2] == '???'): # это значит, что человеку нужно было выбрать 2 курса -> добавляю 3 курс по выбору
        if (elem[1] == '???'):
            df3.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_3']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
            cur += 1
        else:
            if ([elem[1]] == list(data[data['id'] == elem[0]]['fall_3'])): #не добавляю человека, который уже имел такой предмет
                continue
            else:
                df3.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_3']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
                cur += 1
    if (elem[2] == '-' and elem[1] == '???'): #это значит, что человеку нужно было выбрать 1 курс -> добавляю 3 курс по выбору
        df3.loc[cur] = [elem[0] ,list(data[data['id'] == elem[0]]['fall_3']), elem[1], elem[2], list(data[data['id'] == elem[0]].percentile), list(data[data['id'] == elem[0]].Number_spring_courses)]
        cur += 1

df3['fall_next'] = df3['fall_next'].apply(lambda x:x[0])
df3['percentile'] = df3['percentile'].apply(lambda x:x[0])
df3['Number_spring_courses'] = df3['Number_spring_courses'].apply(lambda x:x[0])

# %%
df3.groupby('fall_next').count()
# Out:
#                                                     id  course_1  course_2  \
# fall_next
# Statistical Learning Theory                          2         2         2
# Анализ неструктурированных данных                    3         3         3
# Безопасность компьютерных систем                     2         2         2
# Высокопроизводительные вычисления                    4         4         4
# Матричные вычисления                                10        10        10
# Моделирование временных рядов                        6         6         6
# Принятие решений в условиях риска и неопределён...   1         1         1
# Сбор и обработка данных с помощью краудсорсинга     10        10        10
# Теория баз данных                                    6         6         6
# Язык SQL                                             8         8         8
#
#                                                     percentile  \
# fall_next
# ...

# %%
classes = ['Statistical Learning Theory', 'Анализ неструктурированных данных','Байесовские методы машинного обучения','Безопасность компьютерных систем','Высокопроизводительные вычисления', 'Глубинное обучение в обработке звука','Матричные вычисления', 'Моделирование временных рядов','Принятие решений в условиях риска и неопределённости','Сбор и обработка данных с помощью краудсорсинга','Теория баз данных','Язык SQL'] 
classes_num = [19, 100, 5, 0, 0, 0, 6, 0, 21, 0, 12, 0]
print(len(wave_3))
for i in range(len(classes)):
    ans = df3[df3['fall_next'] == classes[i]].sort_values('percentile')
    ans = ans[0:classes_num[i]]
    for man in ans['id']:
       #final_2.append([man, classes[i]]) тут иду по id которые прошли по второй волне, тут их 52.(Могут быт челы, которые хоть и прошли, но у них курсы с пред совпадают) Должно остаться из 105 -> 54
    
       if (list(ans[ans['id'] == man].Number_spring_courses) == [1]):
             wave_3.append([man, classes[i] , '-']) #полностью закрыты. Тут 8 человек проходят

       if (list(ans[ans['id'] == man].Number_spring_courses) == [2]):
            if (list(ans[ans['id'] == man].course_1) == ['???']): # челы у кого первый курс '???'
                
                wave_3.append([man, classes[i], '???']) # дальше его смотреть не надо, он и по третьей не пройдет
            else: #челы у кого первый курс уже выбран был, второй '???'
                if (list(ans[ans['id'] == man].course_1) == [classes[i]]): # чел который по второй волне проходит на курс где был - послать на третью волну
                    for fl in ans[ans['id'] == man].course_1:
                         wave_3.append([man, fl, '???']) # дальше его смотреть не надо, дальше не проходит по третьей
                else:
                    for fl in ans[ans['id'] == man].course_1:
                        wave_3.append([man, fl , classes[i]]) #закрыли свой второй приоритет


un_id2 =  set(data['id'])
un_final_id2 = set()
print(len(un_id2), "un_id2")
for elem in wave_3:
    un_final_id2.add(elem[0])
un_id2.difference_update(un_final_id2)
print(len(un_id2), "un_id2")
for elem in un_id2:
    for k in wave_2:
        if (elem == k[0]):
            wave_3.append(k)
print(len(wave_3))
# Out:
# 293
# 253bbe1a2021d0404712a1e4acd22939 Statistical Learning Theory -
# f2ed8115db45ef795ced2701fa86515d Statistical Learning Theory -
# 8c3aa7371731bef999519c3de2c47423 Анализ неструктурированных данных -
# 1bbbfae51794b83c769b634be8da7b8d Анализ неструктурированных данных -
# aeb7bb1e047c392b7e5e39225cd86422 Анализ неструктурированных данных -
# 227347077a7d1d0544ddf5643b97cf8c Матричные вычисления -
# 2b0d7dd550bcca4c586cbb27d8478aa8 Матричные вычисления -
# a6ce02b12540bca3cdd15757f8a2e919 Матричные вычисления -
# ac4e2062ca444a506991c212bd2dd872 Матричные вычисления -
# 5a6dfaade650ca8bb2d081342df303e8 Матричные вычисления -
# 00b40fe7dbfd23e5daba765244509415 Матричные вычисления -
# f0f6f3881894172a0f04e79b554b49e6 Принятие решений в условиях риска и неопределённости -
# 5ee2ad618729a6dc3bdb7f2858826ef0 Теория баз данных -
# 1c1623a037bd523d687245e6060e6c5b Теория баз данных -
# 5c49473012411a1eee72f8ea63767adf Теория баз данных -
# ...

# %%
res_fall = pd.DataFrame(columns = ['ID', 'course1', 'course2'])
cur = 0
for elem in wave_3:
    res_fall.loc[cur] = [elem[0], elem[1], elem[2]]
    cur += 1
#data_fin_ = pd.Series(answer_for_fall)
#data_fin_.head()[0]
res_fall.to_csv('res_fall.csv', index=False)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/19782/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
#все в одном месте
# Out:
#     timestamp                                id  rating  18_group  is_mi  \
# 0  2020-05-15  93ff79a51cd602f1dd3028ba2c129503     698     181.0    0.0
# 1  2020-05-15  26b01b1c4cd5656bab18d24c548834fb     647     181.0    0.0
# 2  2020-05-15  30f3653fc176d54e89ac3179c455c6dd     624     185.0    0.0
# 3  2020-05-15  1528f0eaa027580820ccf0d92a53ad68     579     182.0    0.0
# 4  2020-05-15  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0    0.0
#
#                               fall_1                             fall_2  \
# 0                           Язык SQL  Высокопроизводительные вычисления
# 1  Высокопроизводительные вычисления   Безопасность компьютерных систем
# 2   Безопасность компьютерных систем               Матричные вычисления
# 3        Statistical Learning Theory  Высокопроизводительные вычисления
# 4  Высокопроизводительные вычисления   Безопасность компьютерных систем
#
#                           fall_3                spring_1  \
# ...

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/19782/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
